# %% [markdown]
# # TOOL - DRAW DATA

# %%
from drawdata import ScatterWidget

widget = ScatterWidget()
widget
# Out:
# ScatterWidget()

# %%
widget.data_as_pandas
# Out:
#               x           y    color label
# 0    143.652215  431.857707  #1f77b4     a
# 1    127.958303  428.981478  #1f77b4     a
# 2    132.128382  407.129898  #1f77b4     a
# 3    150.037031  400.975085  #1f77b4     a
# 4    167.931167  397.612354  #1f77b4     a
# ..          ...         ...      ...   ...
# 263  522.277390  269.893423  #ff7f0e     b
# 264  517.602654  241.483080  #ff7f0e     b
# 265  510.219372  250.168656  #ff7f0e     b
# 266  488.404618  248.623034  #ff7f0e     b
# 267  512.129789  258.215022  #ff7f0e     b
#
# [268 rows x 4 columns]

# %%
import matplotlib.pylab as plt

df = widget.data_as_pandas
plt.scatter(df["x"], df["y"], color=df["color"])
